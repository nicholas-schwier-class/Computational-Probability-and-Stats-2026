# %% [markdown]
# <a href="https://colab.research.google.com/github/nicholas-schwier-class/Computational-Probability-and-Stats-2026/blob/main/Homework3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Please follow the scenario below and use either permutations or combinations to solve it
#
# A medium sized consulting company assigns temporary 4-digit access codes to managers who are working on short term projects.
#
# These access codes are used to log in to a secure internal system. Because of security concerns, the company enforces the following rules:
#
# - Each access code consists of exactly 4 digits
#
# - Digits are selected from 0 through 9
#
# - No digit may be repeated within a single code
#
# - Order matters because entering the digits in a different order produces a different code
#
# The IT department wants to know how many distinct access codes are possible under these rules in order to evaluate whether the system is sufficiently secure.
#
# ### Question
#
# How many different 4-digit access codes are possible?
#
# You must solve this problem using Python.
