# %% [markdown]
# <a href="https://colab.research.google.com/github/nicholas-schwier-class/Computational-Probability-and-Stats-2026/blob/main/Homework_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Scenario
#
# A cloud service makes 20 independent API calls to a microservice.
#
# Each API call succeeds with probability:
#
# 𝑝=0.9
#
#
# Let the random variable:
#
# 𝑋=number of successful API calls out of 20

# %% [markdown]
# Write Python code to:
#
# Simulate this experiment 10,000 times
#
# Estimate:
# P(X=18)
# P(X≥18)
#
# Plot the distribution of simulated values.
#
# Compare simulated probabilities to theoretical probabilities using scipy.stats.binom.
