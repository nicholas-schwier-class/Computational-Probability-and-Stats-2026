# %% [markdown]
# <a href="https://colab.research.google.com/github/nicholas-schwier-class/Computational-Probability-and-Stats-2026/blob/main/Final_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **QUESTION 1: Normal Distribution & Python**
#
# A standardized test has scores that are approximately normally distributed with a mean of 70 and a standard deviation of 10.
#
#
# **Part A: Data Simulation (Coding)**
#
# Write Python code to:
#
# Generate 1,000 random samples from a normal distribution.
# Store the results in a variable called scores.
#
# **Part B: Probability Calculation (Coding)**
#
# Using Python, estimate the probability that a randomly selected student scores above 85.
#
# Compute this probability in two ways:
# Using the empirical proportion from your simulated data.
# Using the theoretical normal distribution.
#
# **Part C: Visualization (Coding)**
#
# Create a plot that:
#
# Displays the histogram of the simulated scores.
# Overlays the theoretical normal distribution curve.
#
#
# **Part D: Interpretation (Short Answer)**
#
# Compare the empirical and theoretical probabilities. Are they close? Why or why not?
# Explain how increasing the sample size would affect your empirical estimate.
# If the standard deviation increased to 20, how would the shape of the distribution change?

# %%
#WRITE CODE HERE

# %% [markdown]
# WRITE INTERPRETATION HERE

# %% [markdown]
# **QUESTION 2: Linear Regression**
#
# **Part A: Data Generation (Coding)**
#
# Write Python code to:
#
# Generate 100 data points for advertising spend (X) uniformly between 0 and 50.
#
# Generate sales (y) using the model:
#
# y=5+2X+ϵ
#
# where ϵ∼N(0,5) is random noise.
#
# Store the data in variables X and y.
#
# **Part B: Model Fitting (Coding)**
#
# Using Python:
#
# Fit a simple linear regression model to predict y from X.
# Report the estimated intercept and slope.
#
# **Part C: Visualization (Coding)**
#
# Create a plot that:
#
# Shows the scatter plot of the data.
# Overlays the fitted regression line.
# Labels axes clearly.

# %%
#WRITE CODE HERE

# %% [markdown]
# **Question 3: Bayesian Inference with Python**
#
# A disease affects 2% of a population. A diagnostic test has the following properties:
#
# Sensitivity (true positive rate): 0.95
# Specificity (true negative rate): 0.90
#
# **Part A: Prior and Likelihood (Conceptual)**
#
# Define the prior probability that a randomly selected individual has the disease.
# Define the likelihoods:
# P(Positive∣Disease)
# P(Positive∣No Disease)
#
# **Part B: Bayesian Update (Coding)**
#
# Write Python code to compute the posterior probability that a person has the disease given that they tested positive:
#
# P(Disease∣Positive)
#
# Use Bayes’ Rule and clearly show each component in your code.
#
# **Part C: Simulation Approach (Coding)**
#
# Using Python:
#
# Simulate 100,000 individuals.
# Assign disease status based on the prior probability.
# Simulate test results using the given sensitivity and specificity.
# Estimate P(Disease∣Positive) empirically from your simulation.Question

# %% [markdown]
# Write Part A here

# %%
#WRITE CODE HERE
