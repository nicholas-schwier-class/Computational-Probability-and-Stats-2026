# %% [markdown]
# <a href="https://colab.research.google.com/github/nicholas-schwier-class/Computational-Probability-and-Stats-2026/blob/main/Ch3_A_Student.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Random Variables
# Concept
#
# A random variable assigns a number to each outcome of a random experiment.
#
# CS Example:
#
#   Let:
#   X = number of failed login attempts before a successful login

# %% [markdown]
# ## Probability Mass Function (PMF)
# Concept
#
# The PMF gives:
# ![image.png](data:image/png;base64,...)
#
# CS Example:
#
# Suppose a packet transmission succeeds with probability 0.8.
# Let X = 1 if success, 0 if failure.

# %% [markdown]
# ## Independent Random Variables
# Concept
#
# Two random variables are independent if:
# ![image.png](data:image/png;base64,...)
#
# CS Example:
#
# Two servers fail independently.

# %% [markdown]
# ## Bernoulli Distribution
# Concept
#
# A Bernoulli random variable models a single yes/no experiment.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Geometric Distribution
# Concept
#
# Models number of trials until first success.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Binomial Distribution
# Concept
#
# Number of successes in n independent Bernoulli trials.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Negative Binomial Distribution
# Concept
#
# Number of trials required to achieve r successes.
# ![image.png](data:image/png;base64,...)
