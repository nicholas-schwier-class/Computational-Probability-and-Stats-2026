# %% [markdown]
# <a href="https://colab.research.google.com/github/nicholas-schwier-class/Computational-Probability-and-Stats-2026/blob/main/Ch1_Homework_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Law of Total Probability
# A factory has two machines:
# - Machine A makes 30 percent of the items and has a defect rate of 1 percent.
# - Machine B makes 70 percent of the items and has a defect rate of 4 percent.
#
# Write Python code to:
# - Simulate 20,000 items.
# - Estimate the overall probability that an item is defective.
