# %% [markdown]
# <a href="https://colab.research.google.com/github/nicholas-schwier-class/Computational-Probability-and-Stats-2026/blob/main/Homework_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Problem
#
# A quality control manager inspects a shipment of light bulbs.
#
# The shipment contains 50 light bulbs.
#
# 8 bulbs are defective.
#
# The manager randomly selects 6 bulbs for inspection.
#
# The bulbs are selected without replacement.
#
# Let X represent the number of defective bulbs in the sample.'
#
# # Use the correct distribution and find the probability for X
