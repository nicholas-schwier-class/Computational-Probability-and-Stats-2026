# %% [markdown]
# <a href="https://colab.research.google.com/github/nicholas-schwier-class/Computational-Probability-and-Stats-2026/blob/main/Ch5_Student.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Covariance measures how two quantitative variables move together.
#
# Let
# X=hours studied
# Y=exam score
#
# Covariance answers the question:
#
# X tend to occur with larger values of Y?
#
# Interpretation:
#
# Positive covariance: ?
#
# Negative covariance: ?
#
# Covariance near 0: ?

# %% [markdown]
# Interpretation:
#
# Diagonal elements = variances
#
# Off diagonal elements = covariance

# %% [markdown]
# Correlation measures the strength and direction of a linear relationship between two quantitative variables.
#
# In this example we study the relationship between:
#
# X=exercise time (minutes)
#
# Y=calories burned
#
# The sample correlation coefficient is
#
# 𝑟
#
# and is calculated using
#
# ![image.png](data:image/png;base64,...)𝑟
#
#
# where
#
# 𝑠𝑋𝑌=sample covariance
#
# 𝑠𝑋=sample standard deviation of 𝑋
#
# 𝑠𝑌=sample standard deviation of 𝑌
#
#
#
# Interpretation:
#
#
# r>0: positive relationship
#
#
# r<0: negative relationship
#
# r≈0: little linear relationship

# %% [markdown]
# # What is the difference between Covariance and Correlation?
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# A bivariate normal distribution describes the joint behavior of two continuous variables that follow a normal distribution and may be correlated.
#
# In this example we model the relationship between:
#
# X=height (cm)
#
# Y=weight (kg)
#
# The bivariate normal distribution is determined by five parameters:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# The scatterplot visually represents the joint distribution
#
# The center of the ellipse is near
#
# (170,70)
#
# The spread horizontally reflects 𝜎𝑋
#
# The spread vertically reflects σY
# 	​
#
#
# The tilt of the ellipse reflects the correlation 𝜌ρ
