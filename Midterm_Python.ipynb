# %% [markdown]
# <a href="https://colab.research.google.com/github/nicholas-schwier-class/Computational-Probability-and-Stats-2026/blob/main/Midterm_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Question 1:
#
# A login system records whether each login attempt is successful.
#
# Each login attempt is independent.
#
# The probability a login attempt is successful is:
# p=0.65
#
# The system records 10 login attempts.
#
# Let
# X=number of successful logins in 10 attempts
#
#
# (a) Write Python Code (10 points)
#
# Write a Python function that computes:
# P(X=7)
#
# using the binomial probability formula:
# ![image.png](data:image/png;base64,...)
#
#
# Your code must:
#
# Import the math module
#
# Use math.comb() to compute the combination
#
# Store values in clearly named variables
#
# Print the final probability
#
#
# You may assume:
#
# n = 10
# k = 7
# p = 0.65
#
#
#
# (b) Numerical Result (5 points)
#
# Run your code and report the probability rounded to four decimal places.
#
#
# (c) Interpretation (5 points)
#
# Write one complete sentence interpreting your probability in context. Write in text block below this code block

# %%
#QUESTION 1 CODE GOES HERE

# %% [markdown]
# QUESTION 1 TEXT GOES HERE

# %% [markdown]
# # Question 2
#
# A web server receives requests at an average rate of 5 requests per second.
#
# Assume the number of requests per second follows a Poisson distribution.
#
# Let
# X∼Poisson(λ=5)
#
#
# Instructions
#
# Use Python.
# You may use math or scipy.stats.
# Show your code.
# Round all probabilities to three decimal places.
#
# Clearly interpret each numerical answer in a complete sentence.
#
# (a) (6 points)
#
# Write Python code to compute:
# P(X=3)
#
# You must:
# Compute the probability.
# Print the rounded answer.
#
# (b) (6 points)
#
# Compute:
# P(X≤4)
#
# You must:
#
# Either manually sum probabilities
# OR
# Use a cumulative distribution function.
# Show the code.
# Print the rounded answer.

# %%
#QUESTION 2 CODE GOES HERE
