# %% [markdown]
# <a href="https://colab.research.google.com/github/nicholas-schwier-class/Computational-Probability-and-Stats-2026/blob/main/Homework6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# The Central Limit Theorem states that when we repeatedly take samples from a population and compute their means, the distribution of those sample means approaches a normal distribution, even if the original population is not normally distributed (as long as the sample size is sufficiently large).
#
# In this exercise, you will use Python to simulate this phenomenon.
#
# **Part 1: Generate a Non-Normal Population**
#
# Use Python to generate 10,000 random values from an exponential distribution (which is strongly right-skewed).
#
# Plot a histogram of the population values.
#
# Hint: You may use numpy.random.exponential() and matplotlib.
#
# **Part 2: Sampling Distribution of the Mean**
#
# Write a Python function that:
#
# Randomly samples n observations from the population.
#
# Computes the sample mean.
#
# Repeat this process 1,000 times and store all the sample means.
#
# Plot a histogram of the sample means for:
#
#
# n=5
#
# n=30
#
# n=50
#
# **Part 3: Visual Comparison**
#
# Create three histograms (one for each sample size).
#
# Compare them with the histogram of the original population.
