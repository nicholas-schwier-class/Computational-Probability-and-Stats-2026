# %% [markdown]
# <a href="https://colab.research.google.com/github/nicholas-schwier-class/Computational-Probability-and-Stats-2026/blob/main/Ch1_Homework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Conditional Probability Home Work
#
# Homework Problem:
# A company tracks whether customers who visit its website end up making a purchase. Over the course of one week, the site recorded the following data:
# - 1,200 total visitors
# - 300 visitors came from mobile devices
# - 150 mobile visitors made a purchase
# - 180 desktop visitors made a purchase
#
# Write a Python program that:
# 1. Stores this data in appropriate variables.
# 2. Computes the following probabilities:
#     - P(Purchase)
#     - P(Mobile)
#     - P(Purchase | Mobile)
#     - P(Purchase | Desktop)
# 3. Prints each probability with a clear label.
# 4. Checks whether purchasing is more likely for mobile users or desktop users, and prints a message stating which group has the higher conditional probability.

# %%
#Write Code Here
